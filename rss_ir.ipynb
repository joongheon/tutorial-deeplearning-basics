# %%
# !pip install feedparser
# !pip install newspaper3k
# !pip install konlpy

import feedparser
from newspaper import Article
from konlpy.tag import Okt
from collections import Counter
from operator import eq
import numpy as np

urls = ("http://rss.etnews.com/Section901.xml"
	, None)
#	, "http://rss.etnews.com/Section902.xml"
#	, "http://rss.etnews.com/Section903.xml"

def get_tags(text, ntags=50):
	num_unique_words = 0
	num_most_freq = 0
	ranking = 0
	spliter = Okt()
	nouns = spliter.nouns(text)
	count = Counter(nouns)
	return_list = []
	for n, c in count.most_common(ntags):
		ranking = ranking + 1		
		temp = {'tag': n, 'count': c, 'ranking': ranking}
		return_list.append(temp)
		num_unique_words = num_unique_words + 1		
		if num_unique_words == 1:
			num_most_freq = c
	return num_unique_words, num_most_freq, return_list

def TF(request, most_freq, tag):
	return 0.1 + 0.9*Howmanywords(request, tag)/most_freq

def Howmanywords(request, tag):
	nWords = 0
	nRanking = 0
	for n in tag:
		noun = n['tag']
		count = n['count']
		rank = n['ranking']
		if eq(noun, request):
			nWords = count
			nRanking = rank
	return nWords, nRanking

def crawl_rss(urls):
	arr_rss = []
	for url in urls:
		print("[Crawl RSS] ",url)
		parse_rss = feedparser.parse(url)
		for p in parse_rss.entries:
			arr_rss.append({'title':p.title, 'link':p.link})
	return arr_rss
	
def crawl_article(url, language='ko'):
	print("[Crawl Article] ",url)
	var_article = Article(url, language=language)
	var_article.download()
	var_article.parse()
	return var_article.title, var_article.text
	
def main():
	spliter = Okt()
	article_list = crawl_rss(urls)
	print(article_list)
	for article in article_list:
		_, text = crawl_article(article['link'])
		article['text'] = text
	print(article_list)
		
	print('[Parsing Text]')
	for article in article_list:
		num_unique_words, num_most_freq, tags = get_tags(article['text'], 1000)
		article['tags'] = tags
		article['num_unique_words'] = num_unique_words
		article['num_most_freq'] = num_most_freq

	print('[Query]')
	query = input() # query
	for article in article_list:
		n, _ = Howmanywords(query, article['tags'])
		if n != 0:
			print("TF: ", n, article['title'], article['link'])
		
	print('[Parsing Title]')
	for article in article_list:
		article['title_noun'] = spliter.nouns(article['title'])
		print("(중복제거전)")
		print(article['title_noun'])
		print("(중복제거후)")
		print(list(set(article['title_noun'])))
		print("")

	print('[Filtering Fishing Articles]')
	# 기사마다 제목의 각각 명사들이 본문에 몇 번 나오는지 세고 합산결과 출력
	for article in article_list: # 매 기사마다
		n = 0
		for t in list(set(article['title_noun'])): # 매 기사의 제목의 명사마다
			nW, _ = Howmanywords(t, article['tags'])
			n = n + nW
		n = n / len(article['title_noun'])
		print("TF (title): ", format(n, ".2f"), article['title'], article['link'])

	# 문제1) 제목에서 쿼리 검색
	print("[문제1]")
	for article in article_list: # 매 기사마다
		flag = 0
		for t in list(set(article['title_noun'])): # 매 기사의 제목의 명사마다
			if eq(query, t):
				print(article['title'], article['link'])
	
	# 문제2) 본문에서의 쿼리 검색 후, 쿼리의 (TF, TF등수, 제목, URL) 출력
	print("[문제2]")
	for article in article_list:
		n, r = Howmanywords(query, article['tags'])
		if n != 0:
			print("TF: ", n, "TF ranking: ", r, article['title'], article['link'])
		
if __name__ == "__main__":
	main()
# Out:
# Requirement already satisfied: feedparser in /usr/local/lib/python3.6/dist-packages (5.2.1)
# Requirement already satisfied: newspaper3k in /usr/local/lib/python3.6/dist-packages (0.2.8)
# Requirement already satisfied: tldextract>=2.0.1 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (2.2.2)
# Requirement already satisfied: feedfinder2>=0.0.4 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (0.0.4)
# Requirement already satisfied: beautifulsoup4>=4.4.1 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (4.6.0)
# Requirement already satisfied: python-dateutil>=2.5.3 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (2.8.1)
# Requirement already satisfied: tinysegmenter==0.3 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (0.3)
# Requirement already satisfied: PyYAML>=3.11 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (3.13)
# Requirement already satisfied: Pillow>=3.3.0 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (7.0.0)
# Requirement already satisfied: feedparser>=5.2.1 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (5.2.1)
# Requirement already satisfied: jieba3k>=0.35.1 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (0.35.1)
# Requirement already satisfied: requests>=2.10.0 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (2.23.0)
# Requirement already satisfied: nltk>=3.2.1 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (3.2.5)
# Requirement already satisfied: cssselect>=0.9.2 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (1.1.0)
# Requirement already satisfied: lxml>=3.6.0 in /usr/local/lib/python3.6/dist-packages (from newspaper3k) (4.2.6)
# Requirement already satisfied: requests-file>=1.4 in /usr/local/lib/python3.6/dist-packages (from tldextract>=2.0.1->newspaper3k) (1.5.1)
# Requirement already satisfied: idna in /usr/local/lib/python3.6/dist-packages (from tldextract>=2.0.1->newspaper3k) (2.9)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from tldextract>=2.0.1->newspaper3k) (47.1.1)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from feedfinder2>=0.0.4->newspaper3k) (1.12.0)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.10.0->newspaper3k) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.10.0->newspaper3k) (2020.4.5.1)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.10.0->newspaper3k) (1.24.3)
# Requirement already satisfied: konlpy in /usr/local/lib/python3.6/dist-packages (0.5.2)
# Requirement already satisfied: colorama in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.4.3)
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.6/dist-packages (from konlpy) (1.18.5)
# Requirement already satisfied: tweepy>=3.7.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (3.8.0)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.2.6)
# Requirement already satisfied: JPype1>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (0.7.5)
# Requirement already satisfied: beautifulsoup4==4.6.0 in /usr/local/lib/python3.6/dist-packages (from konlpy) (4.6.0)
# Requirement already satisfied: PySocks>=1.5.7 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.7.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.12.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (1.3.0)
# Requirement already satisfied: requests>=2.11.1 in /usr/local/lib/python3.6/dist-packages (from tweepy>=3.7.0->konlpy) (2.23.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->tweepy>=3.7.0->konlpy) (3.1.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests>=2.11.1->tweepy>=3.7.0->konlpy) (3.0.4)
본금리는 0.15∼0.40%P 낮아졌다. 기본 개인 정기적금 1년 이상 2년 미만 금리는 연 0.90%에서 연 0.70%로 내렸다. 주택청약예금 1년 금리는 연 1.25%에서 연 1.05%로 낮아졌다.\n\n\n\n신한은행 역시 수신금리를 최저 0.05%P, 최고 0.5%P 인하했다. 신한S드림 정기예금은 1년 기준 기본 금리가 연 0.9%에서 연 0.6%로 떨어졌다. 신한 주거래 드림 적금은 계약기간 별 금리가 각각 0.3%P 낮아졌다. 1년 기준 기본 금리는 연 0.9%로 바뀌었다.\n\n\n\n한국은행은 지난달 28일 기준금리를 0.75%에서 0.5%로 추가 인하하면서 은행권 연쇄 금리 인하가 발생하고 있다. 신한은행, 농협은행에 앞서 국민은행, 제일은행, 씨티은행, 부산은행, 경남은행, 대구은행, 전북은행이 수신금리 인하 대열에 합류했다.\n\n\n\n아직까지 금리를 내리지 않은 우리은행, 하나은행 역시 조만간 금리를 인하할 전망이다.\n\n\n\n이영호기자 youngtiger@etnews.com'}, {'title': "여야 '원구성' 15일로 연기…주말 합의 이를까", 'link': 'https://www.etnews.com/20200612000169', 'text': '여야가 상임위원장 구성을 두고 합의에 실패해 또다시 원구성이 15일로 연기됐다.\n\n\n\n국회는 12일 본회의를 열었지만 상임위원장 및 예결특위위원장 선출 안건은 상정하지 않고 산회했다.\n\n\n\n박병석 국회의장은 “협상 타결을 기대했지만, 최종 합의에 이르지 못해 유감”이라며 “의장으로서 여야 합의를 마지막으로 촉구하기 위해 3일간 시간을 드리겠다”고 말했다.\n\n\n\n박 의장은 “국가적 위기가 심각하고 민생이 절박함에도 불구하고 오늘 원구성을 마무리짓지 못해 국민들께 송구한 말씀을 드린다”며 “그동안 의장 주재하에 양당 대표가 여러차례 만나 협상을 해왔다. 최종 합의에 이르지 못한 것을 유감스럽게 생각한다”고 말했다.\n\n\n\n이어 “여야 합의를 다시한번 촉구한다. 20대 국회도 6월 13일에 원구성을 했다”며 “21대 국회에서 그 시기보다 늦어지고 있다. 일터 잃고 생계가 어려운분들 국민 목소리를 여야의원들이 모두 가슴에 새기기를 촉구한다”고 강조했다.\n\n\n\n그는 “다음주 15일인 월요일 본회의를 열어 상임위원장 선출의 건을 반드시 처리하겠다”며 “교섭단체 대표들께서는 이제 결단과 리더쉽을 보여주실 것을 당부드린다”고 밝혔다.\n\n\n\n박 의장이 3일간의 협상 시한을 열어준 만큼 여야 원내지도부는 주말에도 만나 협상에 나설 전망이다.\n\n\n\n여야는 예결위, 국토위, 정무위, 문체위, 농림위, 환노위 등 7개 상임위를 야당에 배분하는 방안을 놓고 1차 교감을 이뤘다. 이 외 추가 논의를 거쳐 협의에 이를 수 있을지 주목된다.\n\n\n\n송혜영기자 hybrid@etnews.com'}, {'title': "[국제]샤오미, '미밴드5' 공개... 마그네틱 충전 지원", 'link': 'https://www.etnews.com/20200612000145', 'text': "중국 샤오미가 스마트밴드 신제품 '미밴드5'를 공개했다. 디스플레이 크기를 키우고, 마그네틱 충전 지원으로 편의성을 높이면서 3만원대 저렴한 가격을 유지했다.\n\n\n\n샤오미는 18일 중국 시장에 미밴드5를 공식 출시한다. 가격은 일반 모델 189위안(약 3만2000원), NFC 모델 229위안(약 3만8000원)이다. 국내를 비롯해 해외 시장에도 순차 출시 예정이다.\n\n\n\n미밴드5 디자인은 컬러 디스플레이를 처음으로 적용한 전작 미밴드4와 큰 차이가 없다. 디스플레이 크기를 기존 0.95인치에서 1.2인치로 키우고 인기 애니메이션 스폰지밥과 코난, 에반게리온 등 콜라보 테마도 대거 늘렸다.\n\n눈에 띄는 큰 변화는 충전 방식이다. 미밴드5는 스트랩에서 분리할 필요 없이 본체 아래 충전단자에 자성으로 부착하는 '플러그인' 방식을 새롭게 적용했다. 기존 미밴드 시리즈는 스트랩에서 미밴드 본체를 분리, 전용 충전기에 장착하는 방식으로 불편하다는 의견이 많았다.\n\n심박 측정과 운동 추적 기능도 강화했다. 11가지 피트니스 트래킹 모드를 지원하며 수면 분석과 생리 주기 관리 기능도 제공한다.\n\n\n\nNFC 모델은 중국 지역에 한해 알리페이 등 모바일 결제 서비스를 지원한다. 배터리는 일반 모델 기준 한번 충전으로 최장 20일까지 연속 사용 가능하다.\n\n\n\n박정은기자 jepark@etnews.com"}, {'title': '[국제]애플, 아이폰12 출시 준비 작업 시동... 유럽에 9개 모델 등록', 'link': 'https://www.etnews.com/20200612000144', 'text': '애플이 하반기 아이폰12 출시를 위한 사전 준비 작업에 돌입했다.\n\n\n\n맥루머스 등 외신에 따르면 애플은 아이폰 신제품 9종과 맥 1종을 유라시아경제위원회(ECC) 데이터베이스에 등록했다.\n\n\n\nECC에 새로 등록된 아이폰 모델명은 A2176, A2172, A2341, A2342, A2399, A2403, A2407, A2408, A2411 등이다. 모바일 운영체계(OS)는 iOS13으로 표기됐다.\n\n\n\n외신은 A2176과 A2172은 5.4인치 아이폰12, A2341~A2399는 6.1인치 아이폰12 맥스, A2403~A2411는 아이폰12 프로와 아이폰12프로 맥스로 추정했다. 5세대(5G) 이동통신 모델도 포함됐을 것으로 예상된다.\n\n\n\n애플은 통상 9월 신제품 발표 행사를 통해 아이폰 시리즈를 공개한다. 올해는 코로나19 확산 여파로 오프라인 행사 없이 온라인으로만 발표될 가능성이 높다. 국내에는 10월경 제품 출시가 점쳐진다.\n\n\n\n박정은기자 jepark@etnews.com'}, {'title': "이창환 동서 회장, '식품안전의 날' 동탑산업훈장 수상", 'link': 'https://www.etnews.com/20200612000137', 'text': "이창환 ㈜동서 회장이 12일 서울시 중구 대한상공회의소에서 개최된 '제19회 식품안전의 날' 기념식에서 동탑산업훈장을 수상했다.\n\n\n\n이 회장은 2004년 동서식품 대표이사, 2016년 제20대 한국식품산업협회장을 역임했으며 커피믹스를 중심으로 한 다양한 고품질의 제품을 통해 커피의 대중화를 이끌며 국내 커피시장의 성장을 선도하고 식품산업의 발전에 공헌해왔다.\n\n\n\n또한 국제화된 품질보증 시스템 및 체계적인 소비자 피해 구제 체계 구축, 활발한 사회공헌 활동으로 소비자 중심 경영을 실천한 공로를 인정받아 수상자로 선정됐다.\n\n\n\n한편 식품안전의 날은 식품의약품안전처가 2002년 식품안전관리의 중요성을 알리기 위해 제정한 날로, 식품 관련업계 종사자들의 안전 의식을 향상시키고 식품안전 관리 등에 기여한 유공자를 치하하고 있다.\n\n\n\n이주현기자 jhjh13@etnews.com"}, {'title': '과기정통부 “미세먼지 원인 규명, 근본 문제 해결”', 'link': 'https://www.etnews.com/20200612000084', 'text': "GIST, 미세먼지 최첨단 종합병원 역할 수행\n\n정병선 과학기술정보통신부 차관이 12일 광주과학기술원(GIST·총장 김기선) 미세먼지 연구현장 방문, 연구자들과 간담회를 갖고 미세먼지 측정 장비도 시연했다.\n\n이날 간담회는 과기정통부 미세먼지 R&D 추진전략(2020~2024)' 발표  ...
# [Parsing Text]
# [Query]
# 대기업
# TF:  3 삼성, 현대차 등 대기업, 국회서 여당 만나 '규제완화' 요청 https://www.etnews.com/20200611000246
# TF:  1 7월부터 이어폰 등 3중 포장 안된다...업계 '발만 동동' https://www.etnews.com/20200611000168
# TF:  1 페디셈, 3D 교육 콘텐츠로 반도체 인재 양성한다 https://www.etnews.com/20200611000148
# TF:  4 대기업도 CVC 허용…벤처 투자 '큰돈' 푼다 https://www.etnews.com/20200611000204
# [Parsing Title]
# (중복제거전)
# ['신한', '농협', '금리', '인하', '은행권', '금리']
# (중복제거후)
# ['은행권', '농협', '신한', '인하', '금리']
#
# (중복제거전)
# ['여야', '구성', '연기', '주말', '합의']
# (중복제거후)
# ['합의', '연기', '주말', '구성', '여야']
#
# (중복제거전)
# ['국제', '샤오미', '밴드', '공개', '마', '그네', '충전', '지원']
# (중복제거후)
# ['그네', '국제', '지원', '마', '밴드', '샤오미', '공개', '충전']
#
# (중복제거전)
# ['국제', '애플', '아이폰', '출시', '준비', '작업', '시동', '유럽', '개', '모델', '등록']
# (중복제거후)
# ['국제', '유럽', '모델', '작업', '아이폰', '등록', '출시', '애플', '개', '준비', '시동']
#
# (중복제거전)
# ['이창환', '동서', '회장', '식품', '안전', '날', '탑', '산업', '훈장', '수상']
# (중복제거후)
# ['식품', '날', '수상', '안전', '훈장', '탑', '산업', '회장', '이창환', '동서']
#
# (중복제거전)
# ['과', '정통부', '미세먼지', '원인', '규명', '근본', '문제', '해결']
# (중복제거후)
# ['과', '정통부', '근본', '미세먼지', '원인', '문제', '해결', '규명']
#
# (중복제거전)
# ['셀트리온', '후속', '바이오', '밀러', '글로벌', '임', '돌입']
# (중복제거후)
# ['후속', '바이오', '밀러', '임', '셀트리온', '글로벌', '돌입']
#
# (중복제거전)
# ['수젠텍', '바이오', '직스', '코로나', '중화', '항체', '정량', '검사', '키트', '개발', '추진']
# (중복제거후)
# ['정량', '바이오', '수젠텍', '항체', '코로나', '추진', '개발', '직스', '키트', '검사', '중화']
#
# (중복제거전)
# ['서비스', '로봇', '개발', '위해', '전자', '형제', '한국', '로봇산업', '진흥']
# (중복제거후)
# ['전자', '위해', '형제', '개발', '로봇산업', '진흥', '한국', '서비스', '로봇']
#
# (중복제거전)
# ['과학', '핫이슈', '준위', '방사성폐기물', '지하', '처분']
# (중복제거후)
# ['지하', '준위', '방사성폐기물', '과학', '핫이슈', '처분']
#
# (중복제거전)
# ['코로나', '불확실', '낙관', '정부', '실물', '경제', '하방', '위험', '다소', '완화']
# (중복제거후)
# ['경제', '낙관', '실물', '위험', '정부', '코로나', '완화', '하방', '불확실', '다소']
#
# (중복제거전)
# ['사이트', '배충', '학회', '부회장', '친환', '경차', '보급', '기술', '투자']
# (중복제거후)
# ['보급', '기술', '사이트', '배충', '친환', '부회장', '경차', '학회', '투자']
#
# (중복제거전)
# ['코로나', '신규', '확진', '명', '이틀', '다시', '명대']
# (중복제거후)
# ['이틀', '신규', '코로나', '다시', '확진', '명대', '명']
#
# (중복제거전)
# ['씨', '에스', '글', '비즈', '비즈니스', '전문', '가용', '러기드북', '신제품', '종', '국내', '출시']
# (중복제거후)
# ['종', '신제품', '씨', '가용', '러기드북', '비즈니스', '국내', '글', '출시', '전문', '에스', '비즈']
#
# (중복제거전)
# ['바로', '국가', '유공', '유족', '상해', '보험료', '무상', '지원']
# (중복제거후)
# ['지원', '국가', '무상', '바로', '상해', '보험료', '유공', '유족']
#
# (중복제거전)
# ['중소기업', '우수', '제품', '다생', '각', '다생', '각', '발효', '용기']
# (중복제거후)
# ['중소기업', '발효', '제품', '용기', '우수', '다생', '각']
#
# (중복제거전)
# ['중소기업', '우수', '제품', '닥스메디', '프로', '베티', '에센스', '덴티']
# (중복제거후)
# ['프로', '중소기업', '제품', '우수', '닥스메디', '덴티', '베티', '에센스']
#
# (중복제거전)
# ['넥슨', '옥션', '온라인', '콘텐츠', '네코', '오픈']
# (중복제거후)
# ['오픈', '넥슨', '네코', '콘텐츠', '옥션', '온라인']
#
# (중복제거전)
# ['삼성', '현대차', '등', '대기업', '국회', '여당', '규제', '완화', '요청']
# (중복제거후)
# ['요청', '등', '완화', '대기업', '여당', '현대차', '삼성', '규제', '국회']
#
# (중복제거전)
# ['뉴스', '해설', '한국', '세계', '위', '원동력', '투자', '정책', '지원', '경쟁']
# (중복제거후)
# ['해설', '뉴스', '경쟁', '지원', '원동력', '정책', '한국', '위', '세계', '투자']
#
# (중복제거전)
# ['이어폰', '등', '중', '포장', '업계', '발', '동동']
# (중복제거후)
# ['동동', '등', '이어폰', '업계', '발', '포장', '중']
#
# (중복제거전)
# ['태양광', '전력', '거래', '량', '역대', '최대']
# (중복제거후)
# ['전력', '역대', '최대', '거래', '량', '태양광']
#
# (중복제거전)
# ['페디셈', '교육', '콘텐츠', '반도체', '인재', '양성']
# (중복제거후)
# ['페디셈', '인재', '반도체', '교육', '콘텐츠', '양성']
#
# (중복제거전)
# ['신차', '드라이브', '하늘', '지프', '랭글러', '오버랜드', '파워', '탑']
# (중복제거후)
# ['탑', '오버랜드', '파워', '랭글러', '지프', '드라이브', '신차', '하늘']
#
# (중복제거전)
# ['카', '테크', '시간', '단축', '이', '경쟁력', '자율', '주행', '시뮬레이션', '기술']
# (중복제거후)
# ['기술', '자율', '경쟁력', '시간', '단축', '카', '시뮬레이션', '이', '주행', '테크']
#
# (중복제거전)
# ['최저임금', '첫', '회의', '민노총', '불참', '결정', '난항', '예고']
# (중복제거후)
# ['불참', '결정', '회의', '예고', '난항', '최저임금', '첫', '민노총']
#
# (중복제거전)
# ['대기업', '허용', '처', '투자', '돈']
# (중복제거후)
# ['허용', '처', '대기업', '돈', '투자']
#
# (중복제거전)
# ['여야', '데이터', '청', '필요성', '공감']
# (중복제거후)
# ['공감', '데이터', '필요성', '청', '여야']
#
# (중복제거전)
# ['에듀', '테크', '상용', '교사', '학생', '계정', '하나로', '서비스', '이용']
# (중복제거후)
# ['하나로', '이용', '학생', '계정', '상용', '에듀', '서비스', '교사', '테크']
#
# (중복제거전)
# ['은', '성수', '금융', '위원장', '금융', '분야', '인증', '신원', '확인', '혁신', '방안', '마련', '것']
# (중복제거후)
# ['위원장', '인증', '신원', '성수', '확인', '은', '방안', '분야', '혁신', '마련', '것', '금융']
#
# [Filtering Fishing Articles]
# TF (title):  4.83 신한·농협도 금리 인하…은행권, 잇따라 금리 낮춰 https://www.etnews.com/20200612000185
# TF (title):  3.40 여야 '원구성' 15일로 연기…주말 합의 이를까 https://www.etnews.com/20200612000169
# TF (title):  2.50 [국제]샤오미, '미밴드5' 공개... 마그네틱 충전 지원 https://www.etnews.com/20200612000145
# TF (title):  1.73 [국제]애플, 아이폰12 출시 준비 작업 시동... 유럽에 9개 모델 등록 https://www.etnews.com/20200612000144
# TF (title):  2.30 이창환 동서 회장, '식품안전의 날' 동탑산업훈장 수상 https://www.etnews.com/20200612000137
# TF (title):  6.50 과기정통부 “미세먼지 원인 규명, 근본 문제 해결” https://www.etnews.com/20200612000084
# TF (title):  7.00 셀트리온, 후속 바이오시밀러 글로벌 임상 속속 돌입 https://www.etnews.com/20200612000090
# TF (title):  4.91 수젠텍, 와이바이오로직스와 코로나19 중화항체 정량 검사키트 개발 추진 https://www.etnews.com/20200612000079
# TF (title):  8.11 서비스 로봇 개발 위해 뭉친 LG전자-우아한형제들-한국로봇산업진흥원 https://www.etnews.com/20200612000062
# TF (title):  5.83 [과학핫이슈]고준위방사성폐기물 지하처분 https://www.etnews.com/20200612000074
# TF (title):  1.30 코로나19 불확실성에도 '낙관'...정부 "실물경제 하방위험 다소 완화" https://www.etnews.com/20200612000073
# TF (title):  5.56 [人사이트]배충식 車공학회 부회장 "친환경차 보급보다 기술투자" https://www.etnews.com/20200612000071
